# %%
import pandas as pd
import numpy as np
import altair as alt
import os
from datetime import timedelta
from altair_saver import save

# %%
table_name = 'Untitledt.csv' 
table = pd.read_csv(table_name, delimiter = ';', index_col = 0, skipinitialspace = True)
table
# Out:
#              year                              name                type  \
# number
# 1       1932.0000                       Drum memory            magnetic
# 2       1946.0000             Williams-Kilburn Tube    cathode ray tube
# 3       1949.0000              Magnetic-core memory            magnetic
# 4       1952.0000              Magnetic Band (Tape)            magnetic
# 5       1956.0000                   Hard Disk Drive            magnetic
# 6       1960.0000              Magnetic stripe card            magnetic
# 7       1969.0000                       Floppy Disk            magnetic
# 8       1970.0000                     Bubble Memory            magnetic
# 9       1978.0000   LaserDisc (LD)/Discovision (DV)             optical
# 10      1978.0000           Solid-State-Drive (SSD)          electronic
# 11      1981.0000                 Compact Disc (CD)             optical
# 12      1987.0000          Digital Audio Tape (DAT)  electro-mechanical
# 13      1991.0000                         Mini-Disc     magneto-optical
# 14      1992.0000    Digital Compact Cassette (DCC)            magnetic
# 15      1994.0000                         Zip Drive            magnetic
# 16      1994.0000                 CompactFlash (CF)          electronic
# 17      1995.0000      Digital Versatile Disc (DVD)             optical
# 18      2000.0000                    USB Flash Disk          electronic
# 19      2001.0000          Secure Digital (SD) card          electronic
# 20      2002.0000                 Blu-ray Disc (BD)             optical
# 21      2004.2008  Holographic Versatile Disc (HVD)             optical
# 22      2009.0000          Millennial Disc (M-DISC)             optical
# 23      2016.0000            Chlorine Atomic memory              atomic
# 24      2019.0000                               DNA           molecular
# 25      2019.0000                       Metabolites           molecular
#
#         usage            capacity lifespan  access
# number
# 1       1960s               62500      NaN     0.0
# 2        1955                1000      NaN     1.0
# 3       1970s              100000      NaN     1.0
# 4       today             1000000      NaN     0.0
# 5       today       2000000000000      NaN     1.0
# 6         NaN                 200        3     0.0
# 7       1990s             1440000    5--30     1.0
# 8       1980s              125000      NaN     0.0
# 9        2001           324000000      NaN     1.0
# 10      today       5000000000000      ~10     1.0
# 11      today           700000000       25     1.0
# 12       2005              256000       30     0.0
# 13       2001           140000000    30-40     1.0
# 14       1996           250000000       30     0.0
# 15      1990s            95370000     5-10     1.0
# 16      today        256000000000    70-80     1.0
# 17      today          4500000000       25     1.0
# 18      today       2000000000000       10     1.0
# 19      today     128000000000000       10     1.0
# 20       2019        128000000000  100-150     1.0
# 21      today          3900000000        3     1.0
# 22       2016        100000000000     1000     1.0
# 23      today                1000        U     NaN
# 24      today  215000000000000000      500     0.0
# 25      today               70000      NaN     0.0

# %%
# Used for correcting year representation
def fix_year(year_string):
    return str.split(str(year_string), '.')[0]

# %%
table['year'] = table['year'].apply(fix_year)
table['year'] = pd.to_datetime(table['year'])
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01                   Hard Disk Drive            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1978-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1992-01-01    Digital Compact Cassette (DCC)            magnetic
# 15     1994-01-01                         Zip Drive            magnetic
# 16     1994-01-01                 CompactFlash (CF)          electronic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2016-01-01            Chlorine Atomic memory              atomic
# 24     2019-01-01                               DNA           molecular
# 25     2019-01-01                       Metabolites           molecular
#
#         usage            capacity lifespan  access
# number
# 1       1960s               62500      NaN     0.0
# 2        1955                1000      NaN     1.0
# 3       1970s              100000      NaN     1.0
# 4       today             1000000      NaN     0.0
# 5       today       2000000000000      NaN     1.0
# 6         NaN                 200        3     0.0
# 7       1990s             1440000    5--30     1.0
# 8       1980s              125000      NaN     0.0
# 9        2001           324000000      NaN     1.0
# 10      today       5000000000000      ~10     1.0
# 11      today           700000000       25     1.0
# 12       2005              256000       30     0.0
# 13       2001           140000000    30-40     1.0
# 14       1996           250000000       30     0.0
# 15      1990s            95370000     5-10     1.0
# 16      today        256000000000    70-80     1.0
# 17      today          4500000000       25     1.0
# 18      today       2000000000000       10     1.0
# 19      today     128000000000000       10     1.0
# 20       2019        128000000000  100-150     1.0
# 21      today          3900000000        3     1.0
# 22       2016        100000000000     1000     1.0
# 23      today                1000        U     NaN
# 24      today  215000000000000000      500     0.0
# 25      today               70000      NaN     0.0

# %%
# Add jitter to year values so that we don't have overlapping
value_count = table['year'].value_counts()
value_count.index = pd.to_datetime(value_count.index)
value_count
# Out:
# 1978-01-01    2
# 2019-01-01    2
# 1994-01-01    2
# 1970-01-01    1
# 1956-01-01    1
# 1946-01-01    1
# 2001-01-01    1
# 2009-01-01    1
# 2004-01-01    1
# 1969-01-01    1
# 1995-01-01    1
# 2000-01-01    1
# 1960-01-01    1
# 1932-01-01    1
# 1987-01-01    1
# 2016-01-01    1
# 1981-01-01    1
# 1991-01-01    1
# 1992-01-01    1
# 2002-01-01    1
# 1949-01-01    1
# 1952-01-01    1
# Name: year, dtype: int64

# %%
counter = 0
timestamp_temp = None

for i, row in table.iterrows():
    
    if (timestamp_temp != row['year']):
        timestamp_temp = row['year']
        counter = 0
        
    if (value_count[row['year']] != 1):
        table.at[i, 'year'] = row['year'] + pd.DateOffset(years=counter)
        counter+=1

# %%
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01                   Hard Disk Drive            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1992-01-01    Digital Compact Cassette (DCC)            magnetic
# 15     1994-01-01                         Zip Drive            magnetic
# 16     1995-01-01                 CompactFlash (CF)          electronic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2016-01-01            Chlorine Atomic memory              atomic
# 24     2019-01-01                               DNA           molecular
# 25     2020-01-01                       Metabolites           molecular
#
#         usage            capacity lifespan  access
# number
# 1       1960s               62500      NaN     0.0
# 2        1955                1000      NaN     1.0
# 3       1970s              100000      NaN     1.0
# 4       today             1000000      NaN     0.0
# 5       today       2000000000000      NaN     1.0
# 6         NaN                 200        3     0.0
# 7       1990s             1440000    5--30     1.0
# 8       1980s              125000      NaN     0.0
# 9        2001           324000000      NaN     1.0
# 10      today       5000000000000      ~10     1.0
# 11      today           700000000       25     1.0
# 12       2005              256000       30     0.0
# 13       2001           140000000    30-40     1.0
# 14       1996           250000000       30     0.0
# 15      1990s            95370000     5-10     1.0
# 16      today        256000000000    70-80     1.0
# 17      today          4500000000       25     1.0
# 18      today       2000000000000       10     1.0
# 19      today     128000000000000       10     1.0
# 20       2019        128000000000  100-150     1.0
# 21      today          3900000000        3     1.0
# 22       2016        100000000000     1000     1.0
# 23      today                1000        U     NaN
# 24      today  215000000000000000      500     0.0
# 25      today               70000      NaN     0.0

# %%
storage_types = table['type']
storage_types = storage_types.unique().astype(str)
storage_types
# Out:
# array(['magnetic', 'cathode ray tube', 'optical', 'electronic',
#        'electro-mechanical', 'magneto-optical', 'atomic', 'molecular'],
#       dtype='<U18')

# %%
# Defining colors

pink_custom = '#CD7DA9' #alt.value('rgb(205, 125, 169)')
blue_custom = '#2476B6' #alt.value('rgb(36, 118, 182)')
orange_custom = '#E6A02E' #alt.value('rgb(230, 160, 46)')
green_custom = '#479F77' #alt.value('rgb(71, 159, 119)')
red_custom = '#D73F47' #alt.value('rgb(215, 63, 71)')
gray_custom = '#BCBCBC' #alt.value('rgb(188, 188, 188)')

# Defining global variables
strokeWidth_var = 3
chartWidth_var = 600

# %% [markdown]
# # 1. Creating chart: x = year, y = access

# %%
first_chart_access = alt.Chart(data = table).mark_circle(size=100, opacity = 1).encode(
    alt.X('year:T'),
    alt.Y('access:N'),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None)
)

# %%
first_chart_access
# Out:
# alt.Chart(...)

# %%
second_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = blue_custom, fill = gray_custom).encode(
    alt.X('year:T'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = None),
).properties(
    width=600
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_access
# Out:
# alt.Chart(...)

# %%
third_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'gray', fill = 'white').encode(
    alt.X('year:T'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = None),
).properties(
    width=600
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_access
# Out:
# alt.Chart(...)

# %%
fourth_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'black', fill = 'white').encode(
    alt.X('year:T'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = None)
).properties(
    width=600
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_access
# Out:
# alt.Chart(...)

# %%
final_chart_access = first_chart_access + second_chart_access + third_chart_access + fourth_chart_access

# %%
final_chart_access = final_chart_access.properties(width = chartWidth_var)
final_chart_access
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 2. Creating chart: x = capacity, y = name

# %%
table['capacity_float'] = table['capacity'].astype(float)
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01                   Hard Disk Drive            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1992-01-01    Digital Compact Cassette (DCC)            magnetic
# 15     1994-01-01                         Zip Drive            magnetic
# 16     1995-01-01                 CompactFlash (CF)          electronic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2016-01-01            Chlorine Atomic memory              atomic
# 24     2019-01-01                               DNA           molecular
# 25     2020-01-01                       Metabolites           molecular
#
#         usage            capacity lifespan  access  capacity_float
# number
# 1       1960s               62500      NaN     0.0    6.250000e+04
# 2        1955                1000      NaN     1.0    1.000000e+03
# 3       1970s              100000      NaN     1.0    1.000000e+05
# 4       today             1000000      NaN     0.0    1.000000e+06
# 5       today       2000000000000      NaN     1.0    2.000000e+12
# 6         NaN                 200        3     0.0    2.000000e+02
# 7       1990s             1440000    5--30     1.0    1.440000e+06
# 8       1980s              125000      NaN     0.0    1.250000e+05
# 9        2001           324000000      NaN     1.0    3.240000e+08
# 10      today       5000000000000      ~10     1.0    5.000000e+12
# 11      today           700000000       25     1.0    7.000000e+08
# 12       2005              256000       30     0.0    2.560000e+05
# 13       2001           140000000    30-40     1.0    1.400000e+08
# 14       1996           250000000       30     0.0    2.500000e+08
# 15      1990s            95370000     5-10     1.0    9.537000e+07
# 16      today        256000000000    70-80     1.0    2.560000e+11
# 17      today          4500000000       25     1.0    4.500000e+09
# 18      today       2000000000000       10     1.0    2.000000e+12
# 19      today     128000000000000       10     1.0    1.280000e+14
# 20       2019        128000000000  100-150     1.0    1.280000e+11
# 21      today          3900000000        3     1.0    3.900000e+09
# 22       2016        100000000000     1000     1.0    1.000000e+11
# 23      today                1000        U     NaN    1.000000e+03
# 24      today  215000000000000000      500     0.0    2.150000e+17
# 25      today               70000      NaN     0.0    7.000000e+04

# %% [markdown]
# ===================================================================
# ### Important: For some reason, this cannot be done as bar plots
# ===================================================================

# %%
first_chart_capacity = alt.Chart(data = table).mark_circle(size=100, opacity = 1).encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', zero = True, nice = True), axis=alt.Axis(format=".1e")),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None),
)

# %%
first_chart_capacity
# Out:
# alt.Chart(...)

# %%
second_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = blue_custom, fill = gray_custom).encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', zero = True)),
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_capacity
# Out:
# alt.Chart(...)

# %%
third_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = gray_custom, fill = 'white').encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', zero = True)),
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_capacity
# Out:
# alt.Chart(...)

# %%
fourth_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'black', fill = 'white').encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', zero = True)),
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_capacity
# Out:
# alt.Chart(...)

# %%
final_chart_capacity = first_chart_capacity + second_chart_capacity + third_chart_capacity + fourth_chart_capacity

# %%
final_chart_capacity = final_chart_capacity.properties(width = chartWidth_var)
final_chart_capacity
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 3. Creating chart: x = year/usage, y = name

# %%
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01                   Hard Disk Drive            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1992-01-01    Digital Compact Cassette (DCC)            magnetic
# 15     1994-01-01                         Zip Drive            magnetic
# 16     1995-01-01                 CompactFlash (CF)          electronic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2016-01-01            Chlorine Atomic memory              atomic
# 24     2019-01-01                               DNA           molecular
# 25     2020-01-01                       Metabolites           molecular
#
#         usage            capacity lifespan  access  capacity_float
# number
# 1       1960s               62500      NaN     0.0    6.250000e+04
# 2        1955                1000      NaN     1.0    1.000000e+03
# 3       1970s              100000      NaN     1.0    1.000000e+05
# 4       today             1000000      NaN     0.0    1.000000e+06
# 5       today       2000000000000      NaN     1.0    2.000000e+12
# 6         NaN                 200        3     0.0    2.000000e+02
# 7       1990s             1440000    5--30     1.0    1.440000e+06
# 8       1980s              125000      NaN     0.0    1.250000e+05
# 9        2001           324000000      NaN     1.0    3.240000e+08
# 10      today       5000000000000      ~10     1.0    5.000000e+12
# 11      today           700000000       25     1.0    7.000000e+08
# 12       2005              256000       30     0.0    2.560000e+05
# 13       2001           140000000    30-40     1.0    1.400000e+08
# 14       1996           250000000       30     0.0    2.500000e+08
# 15      1990s            95370000     5-10     1.0    9.537000e+07
# 16      today        256000000000    70-80     1.0    2.560000e+11
# 17      today          4500000000       25     1.0    4.500000e+09
# 18      today       2000000000000       10     1.0    2.000000e+12
# 19      today     128000000000000       10     1.0    1.280000e+14
# 20       2019        128000000000  100-150     1.0    1.280000e+11
# 21      today          3900000000        3     1.0    3.900000e+09
# 22       2016        100000000000     1000     1.0    1.000000e+11
# 23      today                1000        U     NaN    1.000000e+03
# 24      today  215000000000000000      500     0.0    2.150000e+17
# 25      today               70000      NaN     0.0    7.000000e+04

# %%
# Modifying table column "usage"
def fix_usage(year_string):
    if year_string == 'today':
        year_string = '2021'
    elif year_string[-1] == 's':
        year_string = year_string[:-2] + '5'
    return year_string

table['usage'] = table['usage'].astype(str)
table['usage'] = table['usage'].apply(fix_usage)
table['usage'] = pd.to_datetime(table['usage'])
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01                   Hard Disk Drive            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1992-01-01    Digital Compact Cassette (DCC)            magnetic
# 15     1994-01-01                         Zip Drive            magnetic
# 16     1995-01-01                 CompactFlash (CF)          electronic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2016-01-01            Chlorine Atomic memory              atomic
# 24     2019-01-01                               DNA           molecular
# 25     2020-01-01                       Metabolites           molecular
#
#             usage            capacity lifespan  access  capacity_float
# number
# 1      1965-01-01               62500      NaN     0.0    6.250000e+04
# 2      1955-01-01                1000      NaN     1.0    1.000000e+03
# 3      1975-01-01              100000      NaN     1.0    1.000000e+05
# 4      2021-01-01             1000000      NaN     0.0    1.000000e+06
# 5      2021-01-01       2000000000000      NaN     1.0    2.000000e+12
# 6             NaT                 200        3     0.0    2.000000e+02
# 7      1995-01-01             1440000    5--30     1.0    1.440000e+06
# 8      1985-01-01              125000      NaN     0.0    1.250000e+05
# 9      2001-01-01           324000000      NaN     1.0    3.240000e+08
# 10     2021-01-01       5000000000000      ~10     1.0    5.000000e+12
# 11     2021-01-01           700000000       25     1.0    7.000000e+08
# 12     2005-01-01              256000       30     0.0    2.560000e+05
# 13     2001-01-01           140000000    30-40     1.0    1.400000e+08
# 14     1996-01-01           250000000       30     0.0    2.500000e+08
# 15     1995-01-01            95370000     5-10     1.0    9.537000e+07
# 16     2021-01-01        256000000000    70-80     1.0    2.560000e+11
# 17     2021-01-01          4500000000       25     1.0    4.500000e+09
# 18     2021-01-01       2000000000000       10     1.0    2.000000e+12
# 19     2021-01-01     128000000000000       10     1.0    1.280000e+14
# 20     2019-01-01        128000000000  100-150     1.0    1.280000e+11
# 21     2021-01-01          3900000000        3     1.0    3.900000e+09
# 22     2016-01-01        100000000000     1000     1.0    1.000000e+11
# 23     2021-01-01                1000        U     NaN    1.000000e+03
# 24     2021-01-01  215000000000000000      500     0.0    2.150000e+17
# 25     2021-01-01               70000      NaN     0.0    7.000000e+04

# %%
first_chart_usage = alt.Chart(data = table).mark_bar().encode(
    alt.X('year:T', axis = alt.Axis(tickCount = 50)),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None),
)

# %%
first_chart_usage
# Out:
# alt.Chart(...)

# %%
second_chart_usage = alt.Chart(data = table).mark_bar(stroke = blue_custom, fill = gray_custom, strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_usage
# Out:
# alt.Chart(...)

# %%
third_chart_usage = alt.Chart(data = table).mark_bar(stroke = gray_custom, fill = 'white', strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_usage
# Out:
# alt.Chart(...)

# %%
fourth_chart_usage = alt.Chart(data = table).mark_bar(stroke = 'black', fill = 'white', strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_usage
# Out:
# alt.Chart(...)

# %%
final_chart_usage = first_chart_usage + second_chart_usage + third_chart_usage + fourth_chart_usage

# %%
final_chart_usage = final_chart_usage.properties(width = chartWidth_var)
final_chart_usage
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 4. Saving figures

# %%
root_save_path = 'Output'

save(final_chart_access, os.path.join(root_save_path, 'Year_access.pdf'))
save(final_chart_capacity, os.path.join(root_save_path, 'Capacity_name.pdf'))
save(final_chart_usage, os.path.join(root_save_path, 'Usage_name.pdf'))
# Out:
# WARN Channel opacity should not be used with an unsorted discrete field.
# WARN Channel opacity should not be used with an unsorted discrete field.
# WARN Channel opacity should not be used with an unsorted discrete field.
# WARN y-scale's "zero" is dropped as it does not work with log scale.
# WARN y-scale's "zero" is dropped as it does not work with log scale.
# WARN y-scale's "zero" is dropped as it does not work with log scale.
# WARN y-scale's "zero" is dropped as it does not work with log scale.

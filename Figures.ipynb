# %%
import pandas as pd
import numpy as np
import altair as alt
import os
from datetime import timedelta
from altair_saver import save

# %%
# Function that changes font family globaly
def cmroman():
    font = "CM Mono"
    
    return {
        "config" : {
             "title": {'font': font},
             "axis": {
                  "labelFont": font,
                  "titleFont": font
             },
             "header": {
                  "labelFont": font,
                  "titleFont": font
             },
             "legend": {
                  "labelFont": font,
                  "titleFont": font
             }
        }
    }

alt.themes.register('cmroman', cmroman)
alt.themes.enable('cmroman')
# Out:
# ThemeRegistry.enable('cmroman')

# %%
table_name = 'ori.dat' 
table = pd.read_csv(table_name, delimiter = ';', index_col = 0, skipinitialspace = True)
table
# Out:
#         year                              name                type  usage  \
# number
# 1       1932                       Drum memory            magnetic  1960s
# 2       1946             Williams-Kilburn Tube    cathode ray tube   1955
# 3       1949              Magnetic-core memory            magnetic  1970s
# 4       1952              Magnetic Band (Tape)            magnetic  today
# 5       1956             Hard Disk Drive (HDD)            magnetic  today
# 6       1960              Magnetic stripe card            magnetic  today
# 7       1969                       Floppy Disk            magnetic  1990s
# 8       1970                     Bubble Memory            magnetic  1980s
# 9       1978   LaserDisc (LD)/Discovision (DV)             optical   2001
# 10      1978           Solid-State-Drive (SSD)          electronic  today
# 11      1981                 Compact Disc (CD)             optical  today
# 12      1987          Digital Audio Tape (DAT)  electro-mechanical   2005
# 13      1991                         Mini-Disc     magneto-optical   2001
# 14      1994                         Zip Drive            magnetic  1990s
# 15      1994                 CompactFlash (CF)          electronic  today
# 16      1995    Digital Compact Cassette (DCC)            magnetic   1996
# 17      1995      Digital Versatile Disc (DVD)             optical  today
# 18      2000                    USB Flash Disk          electronic  today
# 19      2001          Secure Digital (SD) card          electronic  today
# 20      2002                 Blu-ray Disc (BD)             optical  today
# 21      2004  Holographic Versatile Disc (HVD)             optical   2008
# 22      2009          Millennial Disc (M-DISC)             optical   2016
# 23      2010                     Cell cultures           molecular  today
# 24      2014       Colloidal particle clusters              atomic  today
# 25      2016            Chlorine Atomic memory              atomic  today
# 27      2010                     Synthetic DNA           molecular  today
# 28      2019             Synthetic Metabolomes           molecular  today
#
#                capacity lifespan  addressability  mutability  accessability  \
# number
# 1                 62500      NaN             0.0           2              0
# 2                  1000      NaN             0.0           2              1
# 3                100000      NaN             1.0           2              1
# 4       330000000000000      NaN             0.0           2              0
# 5         2000000000000      NaN             1.0           2              1
# 6                   200        3             0.0           2              0
# 7               1440000    5--30             1.0           2              1
# 8                125000      NaN             0.0           2              0
# 9             324000000      NaN             1.0           2              1
# 10      100000000000000      ~10             1.0           2              1
# 11            700000000       25             1.0           2              1
# 12               256000       30             0.0           2              0
# 13            140000000    30-40             1.0           2              1
# 14             95370000     5-10             1.0           2              1
# 15         256000000000    70-80             1.0           2              1
# 16            250000000       30             0.0           2              0
# 17           4500000000       25             1.0           2              1
# 18        2000000000000       10             1.0           2              1
# 19        2000000000000       10             1.0           2              1
# 20         128000000000  100-150             1.0           2              1
# 21         200000000000        3             1.0           2              1
# 22         100000000000     1000             1.0           0              1
# 23               445000      NaN             0.0           1              0
# 24                    1      NaN             0.0           2              0
# 25                 1000      NaN             NaN           2              1
# 27             22000000      500             0.0           0              0
# 28                70000      NaN             0.0           0              0
#
#         Unnamed: 10
# number
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 27              NaN
# 28              NaN

# %%
# Used for correcting year representation
def fix_year(year_string):
    return str.split(str(year_string), '.')[0]

# %%
table['year'] = table['year'].apply(fix_year)
table['year'] = pd.to_datetime(table['year'])
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01             Hard Disk Drive (HDD)            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1978-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1994-01-01                         Zip Drive            magnetic
# 15     1994-01-01                 CompactFlash (CF)          electronic
# 16     1995-01-01    Digital Compact Cassette (DCC)            magnetic
# 17     1995-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2010-01-01                     Cell cultures           molecular
# 24     2014-01-01       Colloidal particle clusters              atomic
# 25     2016-01-01            Chlorine Atomic memory              atomic
# 27     2010-01-01                     Synthetic DNA           molecular
# 28     2019-01-01             Synthetic Metabolomes           molecular
#
#         usage         capacity lifespan  addressability  mutability  \
# number
# 1       1960s            62500      NaN             0.0           2
# 2        1955             1000      NaN             0.0           2
# 3       1970s           100000      NaN             1.0           2
# 4       today  330000000000000      NaN             0.0           2
# 5       today    2000000000000      NaN             1.0           2
# 6       today              200        3             0.0           2
# 7       1990s          1440000    5--30             1.0           2
# 8       1980s           125000      NaN             0.0           2
# 9        2001        324000000      NaN             1.0           2
# 10      today  100000000000000      ~10             1.0           2
# 11      today        700000000       25             1.0           2
# 12       2005           256000       30             0.0           2
# 13       2001        140000000    30-40             1.0           2
# 14      1990s         95370000     5-10             1.0           2
# 15      today     256000000000    70-80             1.0           2
# 16       1996        250000000       30             0.0           2
# 17      today       4500000000       25             1.0           2
# 18      today    2000000000000       10             1.0           2
# 19      today    2000000000000       10             1.0           2
# 20      today     128000000000  100-150             1.0           2
# 21       2008     200000000000        3             1.0           2
# 22       2016     100000000000     1000             1.0           0
# 23      today           445000      NaN             0.0           1
# 24      today                1      NaN             0.0           2
# 25      today             1000      NaN             NaN           2
# 27      today         22000000      500             0.0           0
# 28      today            70000      NaN             0.0           0
#
#         accessability  Unnamed: 10
# number
# 1                   0          NaN
# 2                   1          NaN
# 3                   1          NaN
# 4                   0          NaN
# 5                   1          NaN
# 6                   0          NaN
# 7                   1          NaN
# 8                   0          NaN
# 9                   1          NaN
# 10                  1          NaN
# 11                  1          NaN
# 12                  0          NaN
# 13                  1          NaN
# 14                  1          NaN
# 15                  1          NaN
# 16                  0          NaN
# 17                  1          NaN
# 18                  1          NaN
# 19                  1          NaN
# 20                  1          NaN
# 21                  1          NaN
# 22                  1          NaN
# 23                  0          NaN
# 24                  0          NaN
# 25                  1          NaN
# 27                  0          NaN
# 28                  0          NaN

# %%
# Add jitter to year values so that we don't have overlapping
value_count = table['year'].value_counts()
value_count.index = pd.to_datetime(value_count.index)
value_count
# Out:
# 1994-01-01    2
# 2010-01-01    2
# 1978-01-01    2
# 1995-01-01    2
# 2000-01-01    1
# 1946-01-01    1
# 2001-01-01    1
# 2009-01-01    1
# 2004-01-01    1
# 1969-01-01    1
# 2019-01-01    1
# 1956-01-01    1
# 1970-01-01    1
# 1960-01-01    1
# 1932-01-01    1
# 1987-01-01    1
# 2016-01-01    1
# 1981-01-01    1
# 1991-01-01    1
# 2002-01-01    1
# 1949-01-01    1
# 2014-01-01    1
# 1952-01-01    1
# Name: year, dtype: int64

# %%
counter = 0
timestamp_temp = None

for i, row in table.iterrows():
    
    if (timestamp_temp != row['year']):
        timestamp_temp = row['year']
        counter = 0
        
    if (value_count[row['year']] != 1):
        table.at[i, 'year'] = row['year'] + pd.DateOffset(years=counter)
        counter+=1

# %%
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01             Hard Disk Drive (HDD)            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1994-01-01                         Zip Drive            magnetic
# 15     1995-01-01                 CompactFlash (CF)          electronic
# 16     1995-01-01    Digital Compact Cassette (DCC)            magnetic
# 17     1996-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2010-01-01                     Cell cultures           molecular
# 24     2014-01-01       Colloidal particle clusters              atomic
# 25     2016-01-01            Chlorine Atomic memory              atomic
# 27     2010-01-01                     Synthetic DNA           molecular
# 28     2019-01-01             Synthetic Metabolomes           molecular
#
#         usage         capacity lifespan  addressability  mutability  \
# number
# 1       1960s            62500      NaN             0.0           2
# 2        1955             1000      NaN             0.0           2
# 3       1970s           100000      NaN             1.0           2
# 4       today  330000000000000      NaN             0.0           2
# 5       today    2000000000000      NaN             1.0           2
# 6       today              200        3             0.0           2
# 7       1990s          1440000    5--30             1.0           2
# 8       1980s           125000      NaN             0.0           2
# 9        2001        324000000      NaN             1.0           2
# 10      today  100000000000000      ~10             1.0           2
# 11      today        700000000       25             1.0           2
# 12       2005           256000       30             0.0           2
# 13       2001        140000000    30-40             1.0           2
# 14      1990s         95370000     5-10             1.0           2
# 15      today     256000000000    70-80             1.0           2
# 16       1996        250000000       30             0.0           2
# 17      today       4500000000       25             1.0           2
# 18      today    2000000000000       10             1.0           2
# 19      today    2000000000000       10             1.0           2
# 20      today     128000000000  100-150             1.0           2
# 21       2008     200000000000        3             1.0           2
# 22       2016     100000000000     1000             1.0           0
# 23      today           445000      NaN             0.0           1
# 24      today                1      NaN             0.0           2
# 25      today             1000      NaN             NaN           2
# 27      today         22000000      500             0.0           0
# 28      today            70000      NaN             0.0           0
#
#         accessability  Unnamed: 10
# number
# 1                   0          NaN
# 2                   1          NaN
# 3                   1          NaN
# 4                   0          NaN
# 5                   1          NaN
# 6                   0          NaN
# 7                   1          NaN
# 8                   0          NaN
# 9                   1          NaN
# 10                  1          NaN
# 11                  1          NaN
# 12                  0          NaN
# 13                  1          NaN
# 14                  1          NaN
# 15                  1          NaN
# 16                  0          NaN
# 17                  1          NaN
# 18                  1          NaN
# 19                  1          NaN
# 20                  1          NaN
# 21                  1          NaN
# 22                  1          NaN
# 23                  0          NaN
# 24                  0          NaN
# 25                  1          NaN
# 27                  0          NaN
# 28                  0          NaN

# %%
storage_types = table['type']
storage_types = storage_types.unique().astype(str)
storage_types
# Out:
# array(['magnetic', 'cathode ray tube', 'optical', 'electronic',
#        'electro-mechanical', 'magneto-optical', 'molecular', 'atomic'],
#       dtype='<U18')

# %%
# Defining colors

pink_custom = '#CD7DA9' #alt.value('rgb(205, 125, 169)')
blue_custom = '#2476B6' #alt.value('rgb(36, 118, 182)')
orange_custom = '#E6A02E' #alt.value('rgb(230, 160, 46)')
green_custom = '#479F77' #alt.value('rgb(71, 159, 119)')
red_custom = '#D73F47' #alt.value('rgb(215, 63, 71)')
gray_custom = '#BCBCBC' #alt.value('rgb(188, 188, 188)')

# Defining global variables
strokeWidth_var = 3
chartWidth_var = 600

# %% [markdown]
# # 1. Creating chart: x = year, y = access

# %%
first_chart_access = alt.Chart(data = table).mark_circle(size=100, opacity = 1).encode(
    alt.X('year:T'),
    alt.Y('accessability:N'),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None)
)

# %%
first_chart_access
# Out:
# alt.Chart(...)

# %%
second_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = blue_custom, fill = gray_custom).encode(
    alt.X('year:T'),
    alt.Y('accessability:N'),
    alt.Opacity('type:N', legend = None),
).properties(
    width=600
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_access
# Out:
# alt.Chart(...)

# %%
third_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'gray', fill = 'white').encode(
    alt.X('year:T'),
    alt.Y('accessability:N'),
    alt.Opacity('type:N', legend = None),
).properties(
    width=600
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_access
# Out:
# alt.Chart(...)

# %%
fourth_chart_access = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'black', fill = 'white').encode(
    alt.X('year:T', scale = alt.Scale (nice = True), axis = alt.Axis(title = None)),
    alt.Y('accessability:N', axis = alt.Axis(title = None)),
    alt.Opacity('type:N', legend = None)
).properties(
    width=600
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_access
# Out:
# alt.Chart(...)

# %%
final_chart_access = first_chart_access + second_chart_access + third_chart_access + fourth_chart_access

# %%
final_chart_access = final_chart_access.properties(width = chartWidth_var)
final_chart_access
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 2. Creating chart: x = capacity, y = name

# %%
table['capacity_float'] = table['capacity'].astype(float)
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01             Hard Disk Drive (HDD)            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1994-01-01                         Zip Drive            magnetic
# 15     1995-01-01                 CompactFlash (CF)          electronic
# 16     1995-01-01    Digital Compact Cassette (DCC)            magnetic
# 17     1996-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2010-01-01                     Cell cultures           molecular
# 24     2014-01-01       Colloidal particle clusters              atomic
# 25     2016-01-01            Chlorine Atomic memory              atomic
# 27     2010-01-01                     Synthetic DNA           molecular
# 28     2019-01-01             Synthetic Metabolomes           molecular
#
#         usage         capacity lifespan  addressability  mutability  \
# number
# 1       1960s            62500      NaN             0.0           2
# 2        1955             1000      NaN             0.0           2
# 3       1970s           100000      NaN             1.0           2
# 4       today  330000000000000      NaN             0.0           2
# 5       today    2000000000000      NaN             1.0           2
# 6       today              200        3             0.0           2
# 7       1990s          1440000    5--30             1.0           2
# 8       1980s           125000      NaN             0.0           2
# 9        2001        324000000      NaN             1.0           2
# 10      today  100000000000000      ~10             1.0           2
# 11      today        700000000       25             1.0           2
# 12       2005           256000       30             0.0           2
# 13       2001        140000000    30-40             1.0           2
# 14      1990s         95370000     5-10             1.0           2
# 15      today     256000000000    70-80             1.0           2
# 16       1996        250000000       30             0.0           2
# 17      today       4500000000       25             1.0           2
# 18      today    2000000000000       10             1.0           2
# 19      today    2000000000000       10             1.0           2
# 20      today     128000000000  100-150             1.0           2
# 21       2008     200000000000        3             1.0           2
# 22       2016     100000000000     1000             1.0           0
# 23      today           445000      NaN             0.0           1
# 24      today                1      NaN             0.0           2
# 25      today             1000      NaN             NaN           2
# 27      today         22000000      500             0.0           0
# 28      today            70000      NaN             0.0           0
#
#         accessability  Unnamed: 10  capacity_float
# number
# 1                   0          NaN    6.250000e+04
# 2                   1          NaN    1.000000e+03
# 3                   1          NaN    1.000000e+05
# 4                   0          NaN    3.300000e+14
# 5                   1          NaN    2.000000e+12
# 6                   0          NaN    2.000000e+02
# 7                   1          NaN    1.440000e+06
# 8                   0          NaN    1.250000e+05
# 9                   1          NaN    3.240000e+08
# 10                  1          NaN    1.000000e+14
# 11                  1          NaN    7.000000e+08
# 12                  0          NaN    2.560000e+05
# 13                  1          NaN    1.400000e+08
# 14                  1          NaN    9.537000e+07
# 15                  1          NaN    2.560000e+11
# 16                  0          NaN    2.500000e+08
# 17                  1          NaN    4.500000e+09
# 18                  1          NaN    2.000000e+12
# 19                  1          NaN    2.000000e+12
# 20                  1          NaN    1.280000e+11
# 21                  1          NaN    2.000000e+11
# 22                  1          NaN    1.000000e+11
# 23                  0          NaN    4.450000e+05
# 24                  0          NaN    1.000000e+00
# 25                  1          NaN    1.000000e+03
# 27                  0          NaN    2.200000e+07
# 28                  0          NaN    7.000000e+04

# %% [markdown]
# ===================================================================
# ### Important: For some reason, this cannot be done as bar plots
# ===================================================================

# %%
first_chart_capacity = alt.Chart(data = table).mark_circle(size=100, opacity = 1).encode(
    alt.X('name:N', sort = None, axis = alt.Axis(title = None, grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', nice = True), axis=alt.Axis(title = None, format=".1e")),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None),
)

# %%
first_chart_capacity
# Out:
# alt.Chart(...)

# %%
second_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = blue_custom, fill = gray_custom).encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log')),
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_capacity
# Out:
# alt.Chart(...)

# %%
third_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = gray_custom, fill = 'white').encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', nice = True)),
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_capacity
# Out:
# alt.Chart(...)

# %%
fourth_chart_capacity = alt.Chart(data = table).mark_circle(size=60, opacity = 1, stroke = 'black', fill = 'white').encode(
    alt.X('name:N', sort = None, axis = alt.Axis(grid = True, labelAngle = -45)),
    alt.Y('capacity_float:Q', scale = alt.Scale(type = 'log', nice = True)),
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_capacity
# Out:
# alt.Chart(...)

# %%
final_chart_capacity = first_chart_capacity + second_chart_capacity + third_chart_capacity + fourth_chart_capacity

# %%
final_chart_capacity = final_chart_capacity.properties(width = chartWidth_var)
final_chart_capacity
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 3. Creating chart: x = year/usage, y = name

# %%
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01             Hard Disk Drive (HDD)            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1994-01-01                         Zip Drive            magnetic
# 15     1995-01-01                 CompactFlash (CF)          electronic
# 16     1995-01-01    Digital Compact Cassette (DCC)            magnetic
# 17     1996-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2010-01-01                     Cell cultures           molecular
# 24     2014-01-01       Colloidal particle clusters              atomic
# 25     2016-01-01            Chlorine Atomic memory              atomic
# 27     2010-01-01                     Synthetic DNA           molecular
# 28     2019-01-01             Synthetic Metabolomes           molecular
#
#         usage         capacity lifespan  addressability  mutability  \
# number
# 1       1960s            62500      NaN             0.0           2
# 2        1955             1000      NaN             0.0           2
# 3       1970s           100000      NaN             1.0           2
# 4       today  330000000000000      NaN             0.0           2
# 5       today    2000000000000      NaN             1.0           2
# 6       today              200        3             0.0           2
# 7       1990s          1440000    5--30             1.0           2
# 8       1980s           125000      NaN             0.0           2
# 9        2001        324000000      NaN             1.0           2
# 10      today  100000000000000      ~10             1.0           2
# 11      today        700000000       25             1.0           2
# 12       2005           256000       30             0.0           2
# 13       2001        140000000    30-40             1.0           2
# 14      1990s         95370000     5-10             1.0           2
# 15      today     256000000000    70-80             1.0           2
# 16       1996        250000000       30             0.0           2
# 17      today       4500000000       25             1.0           2
# 18      today    2000000000000       10             1.0           2
# 19      today    2000000000000       10             1.0           2
# 20      today     128000000000  100-150             1.0           2
# 21       2008     200000000000        3             1.0           2
# 22       2016     100000000000     1000             1.0           0
# 23      today           445000      NaN             0.0           1
# 24      today                1      NaN             0.0           2
# 25      today             1000      NaN             NaN           2
# 27      today         22000000      500             0.0           0
# 28      today            70000      NaN             0.0           0
#
#         accessability  Unnamed: 10  capacity_float
# number
# 1                   0          NaN    6.250000e+04
# 2                   1          NaN    1.000000e+03
# 3                   1          NaN    1.000000e+05
# 4                   0          NaN    3.300000e+14
# 5                   1          NaN    2.000000e+12
# 6                   0          NaN    2.000000e+02
# 7                   1          NaN    1.440000e+06
# 8                   0          NaN    1.250000e+05
# 9                   1          NaN    3.240000e+08
# 10                  1          NaN    1.000000e+14
# 11                  1          NaN    7.000000e+08
# 12                  0          NaN    2.560000e+05
# 13                  1          NaN    1.400000e+08
# 14                  1          NaN    9.537000e+07
# 15                  1          NaN    2.560000e+11
# 16                  0          NaN    2.500000e+08
# 17                  1          NaN    4.500000e+09
# 18                  1          NaN    2.000000e+12
# 19                  1          NaN    2.000000e+12
# 20                  1          NaN    1.280000e+11
# 21                  1          NaN    2.000000e+11
# 22                  1          NaN    1.000000e+11
# 23                  0          NaN    4.450000e+05
# 24                  0          NaN    1.000000e+00
# 25                  1          NaN    1.000000e+03
# 27                  0          NaN    2.200000e+07
# 28                  0          NaN    7.000000e+04

# %%
# Modifying table column "usage"
def fix_usage(year_string):
    if year_string == 'today':
        year_string = '2021'
    elif year_string[-1] == 's':
        year_string = year_string[:-2] + '5'
    return year_string

table['usage'] = table['usage'].astype(str)
table['usage'] = table['usage'].apply(fix_usage)
table['usage'] = pd.to_datetime(table['usage'])
table
# Out:
#              year                              name                type  \
# number
# 1      1932-01-01                       Drum memory            magnetic
# 2      1946-01-01             Williams-Kilburn Tube    cathode ray tube
# 3      1949-01-01              Magnetic-core memory            magnetic
# 4      1952-01-01              Magnetic Band (Tape)            magnetic
# 5      1956-01-01             Hard Disk Drive (HDD)            magnetic
# 6      1960-01-01              Magnetic stripe card            magnetic
# 7      1969-01-01                       Floppy Disk            magnetic
# 8      1970-01-01                     Bubble Memory            magnetic
# 9      1978-01-01   LaserDisc (LD)/Discovision (DV)             optical
# 10     1979-01-01           Solid-State-Drive (SSD)          electronic
# 11     1981-01-01                 Compact Disc (CD)             optical
# 12     1987-01-01          Digital Audio Tape (DAT)  electro-mechanical
# 13     1991-01-01                         Mini-Disc     magneto-optical
# 14     1994-01-01                         Zip Drive            magnetic
# 15     1995-01-01                 CompactFlash (CF)          electronic
# 16     1995-01-01    Digital Compact Cassette (DCC)            magnetic
# 17     1996-01-01      Digital Versatile Disc (DVD)             optical
# 18     2000-01-01                    USB Flash Disk          electronic
# 19     2001-01-01          Secure Digital (SD) card          electronic
# 20     2002-01-01                 Blu-ray Disc (BD)             optical
# 21     2004-01-01  Holographic Versatile Disc (HVD)             optical
# 22     2009-01-01          Millennial Disc (M-DISC)             optical
# 23     2010-01-01                     Cell cultures           molecular
# 24     2014-01-01       Colloidal particle clusters              atomic
# 25     2016-01-01            Chlorine Atomic memory              atomic
# 27     2010-01-01                     Synthetic DNA           molecular
# 28     2019-01-01             Synthetic Metabolomes           molecular
#
#             usage         capacity lifespan  addressability  mutability  \
# number
# 1      1965-01-01            62500      NaN             0.0           2
# 2      1955-01-01             1000      NaN             0.0           2
# 3      1975-01-01           100000      NaN             1.0           2
# 4      2021-01-01  330000000000000      NaN             0.0           2
# 5      2021-01-01    2000000000000      NaN             1.0           2
# 6      2021-01-01              200        3             0.0           2
# 7      1995-01-01          1440000    5--30             1.0           2
# 8      1985-01-01           125000      NaN             0.0           2
# 9      2001-01-01        324000000      NaN             1.0           2
# 10     2021-01-01  100000000000000      ~10             1.0           2
# 11     2021-01-01        700000000       25             1.0           2
# 12     2005-01-01           256000       30             0.0           2
# 13     2001-01-01        140000000    30-40             1.0           2
# 14     1995-01-01         95370000     5-10             1.0           2
# 15     2021-01-01     256000000000    70-80             1.0           2
# 16     1996-01-01        250000000       30             0.0           2
# 17     2021-01-01       4500000000       25             1.0           2
# 18     2021-01-01    2000000000000       10             1.0           2
# 19     2021-01-01    2000000000000       10             1.0           2
# 20     2021-01-01     128000000000  100-150             1.0           2
# 21     2008-01-01     200000000000        3             1.0           2
# 22     2016-01-01     100000000000     1000             1.0           0
# 23     2021-01-01           445000      NaN             0.0           1
# 24     2021-01-01                1      NaN             0.0           2
# 25     2021-01-01             1000      NaN             NaN           2
# 27     2021-01-01         22000000      500             0.0           0
# 28     2021-01-01            70000      NaN             0.0           0
#
#         accessability  Unnamed: 10  capacity_float
# number
# 1                   0          NaN    6.250000e+04
# 2                   1          NaN    1.000000e+03
# 3                   1          NaN    1.000000e+05
# 4                   0          NaN    3.300000e+14
# 5                   1          NaN    2.000000e+12
# 6                   0          NaN    2.000000e+02
# 7                   1          NaN    1.440000e+06
# 8                   0          NaN    1.250000e+05
# 9                   1          NaN    3.240000e+08
# 10                  1          NaN    1.000000e+14
# 11                  1          NaN    7.000000e+08
# 12                  0          NaN    2.560000e+05
# 13                  1          NaN    1.400000e+08
# 14                  1          NaN    9.537000e+07
# 15                  1          NaN    2.560000e+11
# 16                  0          NaN    2.500000e+08
# 17                  1          NaN    4.500000e+09
# 18                  1          NaN    2.000000e+12
# 19                  1          NaN    2.000000e+12
# 20                  1          NaN    1.280000e+11
# 21                  1          NaN    2.000000e+11
# 22                  1          NaN    1.000000e+11
# 23                  0          NaN    4.450000e+05
# 24                  0          NaN    1.000000e+00
# 25                  1          NaN    1.000000e+03
# 27                  0          NaN    2.200000e+07
# 28                  0          NaN    7.000000e+04

# %%
first_chart_usage = alt.Chart(data = table).mark_bar().encode(
    alt.X('year:T', axis = alt.Axis(title = None, tickCount = 50)),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x', axis = alt.Axis(title = None)),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom]), legend = None),
)

# %%
first_chart_usage
# Out:
# alt.Chart(...)

# %%
second_chart_usage = alt.Chart(data = table).mark_bar(stroke = blue_custom, fill = gray_custom, strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart_usage
# Out:
# alt.Chart(...)

# %%
third_chart_usage = alt.Chart(data = table).mark_bar(stroke = gray_custom, fill = 'white', strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "atomic"')

# %%
third_chart_usage
# Out:
# alt.Chart(...)

# %%
fourth_chart_usage = alt.Chart(data = table).mark_bar(stroke = 'black', fill = 'white', strokeWidth = strokeWidth_var).encode(
    alt.X('year:T'),
    alt.X2('usage:T'),
    alt.Y('name:N', sort = 'x'),
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart_usage
# Out:
# alt.Chart(...)

# %%
final_chart_usage = first_chart_usage + second_chart_usage + third_chart_usage + fourth_chart_usage

# %%
final_chart_usage = final_chart_usage.properties(width = chartWidth_var)
final_chart_usage
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # 4. Saving figures

# %% [markdown]
# Important: Due to a bug documented here https://github.com/altair-viz/altair/issues/1954 font changes are not persistent if trying to save as pdf.

# %%
root_save_path = 'Output'

save(final_chart_access, os.path.join(root_save_path, 'Year_access.pdf'))
save(final_chart_capacity, os.path.join(root_save_path, 'Capacity_name.pdf'))
save(final_chart_usage, os.path.join(root_save_path, 'Usage_name.pdf'))

#final_chart_access.save (os.path.join(root_save_path, 'Year_access.png'))
#final_chart_capacity.save (os.path.join(root_save_path, 'Capacity_name.png'))
#final_chart_usage.save (os.path.join(root_save_path, 'Usage_name.png'))
# Out:
# WARN Channel opacity should not be used with an unsorted discrete field.
# WARN Channel opacity should not be used with an unsorted discrete field.
# WARN Channel opacity should not be used with an unsorted discrete field.

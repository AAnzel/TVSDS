# %%
import pandas as pd
import numpy as np
import altair as alt
import os

# %%
table_name = 'Untitledt.csv' 

table = pd.read_csv(table_name, delimiter = ';', index_col = 0, skipinitialspace = True)
table['year'] = table['year'].astype(int)
table
# Out:
#         year                              name                type  usage  \
# number
# 1       1932                       Drum memory            magnetic  1960s
# 2       1946             Williams-Kilburn Tube    cathode ray tube   1955
# 3       1949              Magnetic-core memory            magnetic  1970s
# 4       1952              Magnetic Band (Tape)            magnetic  today
# 5       1956                   Hard Disk Drive            magnetic  today
# 6       1960              Magnetic stripe card            magnetic    NaN
# 7       1969                       Floppy Disk            magnetic  1990s
# 8       1970                     Bubble Memory            magnetic  1980s
# 9       1978   LaserDisc (LD)/Discovision (DV)             optical   2001
# 10      1978           Solid-State-Drive (SSD)          electronic  today
# 11      1981                 Compact Disc (CD)             optical  today
# 12      1987          Digital Audio Tape (DAT)  electro-mechanical   2005
# 13      1991                         Mini-Disc     magneto-optical   2001
# 14      1992    Digital Compact Cassette (DCC)            magnetic   1996
# 15      1994                         Zip Drive            magnetic  1990s
# 16      1994                 CompactFlash (CF)          electronic  today
# 17      1995      Digital Versatile Disc (DVD)             optical  today
# 18      2000                    USB Flash Disk          electronic  today
# 19      2001          Secure Digital (SD) card          electronic  today
# 20      2002                 Blu-ray Disc (BD)             optical   2019
# 21      2004  Holographic Versatile Disc (HVD)             optical  today
# 22      2009          Millennial Disc (M-DISC)             optical   2016
# 23      2016            Chlorine Atomic memory              atomic  today
# 24      2019                               DNA           molecular  today
# 25      2019                       Metabolites           molecular  today
#
#                   capacity lifespan  access
# number
# 1                    62500      NaN     0.0
# 2                     1000      NaN     1.0
# 3                   100000      NaN     1.0
# 4                  1000000      NaN     0.0
# 5            2000000000000      NaN     1.0
# 6                      200        3     0.0
# 7                  1440000    5--30     1.0
# 8                   125000      NaN     0.0
# 9                324000000      NaN     1.0
# 10           5000000000000      ~10     1.0
# 11               700000000       25     1.0
# 12                  256000       30     0.0
# 13               140000000    30-40     1.0
# 14               250000000       30     0.0
# 15                95370000     5-10     1.0
# 16            256000000000    70-80     1.0
# 17              4500000000       25     1.0
# 18           2000000000000       10     1.0
# 19         128000000000000       10     1.0
# 20            128000000000  100-150     1.0
# 21              3900000000        3     1.0
# 22            100000000000     1000     1.0
# 23                    1000        U     NaN
# 24      215000000000000000      500     0.0
# 25                   70000      NaN     0.0

# %%
storage_types = table['type']
storage_types = storage_types.unique().astype(str)
storage_types
# Out:
# array(['magnetic', 'cathode ray tube', 'optical', 'electronic',
#        'electro-mechanical', 'magneto-optical', 'atomic', 'molecular'],
#       dtype='<U18')

# %%
# Defining colors

pink_custom = '#CD7DA9' #alt.value('rgb(205, 125, 169)')
blue_custom = '#2476B6' #alt.value('rgb(36, 118, 182)')
orange_custom = '#E6A02E' #alt.value('rgb(230, 160, 46)')
green_custom = '#479F77' #alt.value('rgb(71, 159, 119)')
red_custom = '#D73F47' #alt.value('rgb(215, 63, 71)')
gray_custom = '#BCBCBC' #alt.value('rgb(188, 188, 188)')

# %%
first_chart = alt.Chart(data = table).mark_circle(size=50).encode(
    alt.X('year:O'),
    alt.Y('access:N'),
    alt.Color('type:N', scale = alt.Scale(domain=['magnetic', 'cathode ray tube', 'optical', 'electronic', 'electro-mechanical'],
                      range=[blue_custom, pink_custom, gray_custom, orange_custom, red_custom])),
).properties(
    width=600
)

# %%
first_chart
# Out:
# alt.Chart(...)

# %%
# https://github.com/altair-viz/altair/issues/984

# %%
second_chart = alt.Chart(data = table).mark_circle(size=30, stroke = blue_custom, fill = gray_custom).encode(
    alt.X('year:O'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = alt.Legend(title = '')),
).properties(
    width=600
).transform_filter ('datum.type == "magneto-optical"')

# %%
second_chart
# Out:
# alt.Chart(...)

# %%
third_chart = alt.Chart(data = table).mark_circle(size=30, stroke = gray_custom, fill = 'white').encode(
    alt.X('year:O'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = alt.Legend(title = '')),
).properties(
    width=600
).transform_filter ('datum.type == "atomic"')

# %%
third_chart
# Out:
# alt.Chart(...)

# %%
table['type']

# %%
fourth_chart = alt.Chart(data = table).mark_circle(size=30, stroke = 'black', fill = 'white').encode(
    alt.X('year:O'),
    alt.Y('access:N'),
    alt.Opacity('type:N', legend = alt.Legend(title = ''))
).properties(
    width=600
).transform_filter ('datum.type == "molecular"')

# %%
fourth_chart
# Out:
# alt.Chart(...)

# %%
semisemifinal_chart = alt.layer(first_chart, second_chart)
semifinal_chart = alt.layer(semisemifinal_chart, third_chart)
final_chart = alt.layer (semifinal_chart, fourth_chart)

# %%
final_chart
# Out:
# alt.LayerChart(...)
